# %%
import pandas as pd
import numpy as np
from scipy.stats import norm, kurtosis, skew, kstest
import os

# %%
PATH1 = r'/Users/jan/Documents/working papers/project 1/data/sp500_1min___2004-01-02___2024-03-18.csv'
PATH2 = r'/Users/jan/Documents/working papers/project 1/data/sp500_1min_2023-07-11___2025-03-31.csv'

df1 = pd.read_csv(PATH1)
df2 = pd.read_csv(PATH2)

# %% [markdown]
# quote_datetime,underlying_bid,underlying_ask,active_underlying_price,implied_underlying_price <- columns in PATH1
# underlying_symbol,quote_datetime,exchange,trade_price,trade_size,trade_condition_id,canceled_trade_condition_id,bid,ask,quote_datetime_minute <- columns in PATH2

# %%
df1.columns = ['quote_datetime' , 'underlying_bid' , 'underlying_ask', 'active_underlying_price', 'implied_underlying_price']
df2.columns = ['index' , 'underlying_symbol' , 'quote_datetime' , 'exchange' , 'trade_price' , 'trade_size' , 'trade_condition_id' , 'canceled_trade_condition_id' , 'bid,ask' , 'quote_datetime_minute']
